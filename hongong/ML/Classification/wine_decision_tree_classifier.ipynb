# %% [markdown]
# # Decision Tree
# ---
# information gain(부모, 자식노드 impurity 차)이 크도록 트리를 구성하고 leaf node의 클래스 비율에 따라 분류하는 모델
#
# 장점: 이해하기 쉽다. scaling이 불필요하다.
#
# (혼공 220p~241p)

# %% [markdown]
# ### Read CSV File

# %%
import pandas as pd
df = pd.read_csv('https://bit.ly/wine_csv_data')
df.head()
# Out:
#    alcohol  sugar    pH  class
# 0      9.4    1.9  3.51    0.0
# 1      9.8    2.6  3.20    0.0
# 2      9.8    2.3  3.26    0.0
# 3      9.8    1.9  3.16    0.0
# 4      9.4    1.9  3.51    0.0

# %%
X = df.drop('class', axis=1)
y = df['class']

print(X.head())
print(X.shape, y.shape)
# Out:
#    alcohol  sugar    pH
# 0      9.4    1.9  3.51
# 1      9.8    2.6  3.20
# 2      9.8    2.3  3.26
# 3      9.8    1.9  3.16
# 4      9.4    1.9  3.51
# (6497, 3) (6497,)

# %% [markdown]
# ### Train, Test Split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, random_state=42
)

# %% [markdown]
# ### 모델 학습

# %%
from sklearn.tree import DecisionTreeClassifier

# max_depth=3인 Decision Tree
dt = DecisionTreeClassifier(max_depth=3, random_state=42)
dt.fit(X_train, y_train)
print(dt.score(X_train, y_train))
print(dt.score(X_test, y_test))
# Out:
# 0.8499589490968801
# 0.8363076923076923

# %% [markdown]
# ### Plot

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

plt.figure(figsize=(15, 8))
plot_tree(dt, filled=True, feature_names=X.columns)
plt.show()

# %% [markdown]
# ### Feature Importance

# %%
dt.feature_importances_
# Out:
# array([0.12871631, 0.86213285, 0.00915084])
