# %%
# import libraries
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torchvision import datasets, transforms

# %%
# 로드할 데이터 정의
transform = transforms.Compose([
    transforms.ToTensor()
])

trainset = datasets.FashionMNIST(
    root = './.data/',
    train=True,
    download=True,
    transform=transform
)

testset = datasets.FashionMNIST(
    root = './.data/',
    train=False,
    download=True,
    transform=transform
)

# %%
# dataset load
BATCH_SIZE = 16

train_loader = torch.utils.data.DataLoader(
    dataset = trainset,
    batch_size = BATCH_SIZE,
    shuffle = True
)

test_loader = torch.utils.data.DataLoader(
    dataset = testset,
    batch_size = BATCH_SIZE,
    shuffle = True
)

# %% [markdown]
# ### DNN 설계

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        # 구조 정의
        self.fc1 = nn.Linear(784, 256)
        self.fc2 = nn.Linear(256, 128)
        self.fc3 = nn.Linear(128, 10) # class 수

    def forward(self, x):
        x = x.view(-1, 784)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# %%
USE_CUDA = torch.cuda.is_available()
DEVICE = torch.device("gpu" if USE_CUDA else "cpu")

# %%
model = Net().to(DEVICE)
EPOCHS = 30
optimizer = optim.SGD(model.parameters(), lr=0.01)

# %%
def train(model, train_loader, optimizer):
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader) :
        data, target = data.to(DEVICE), target.to(DEVICE)
        optimizer.zero_grad()
        output = model(data)
        loss = F.cross_entropy(output, target)
        loss.backward()
        optimizer.step()

# %%
# model 성능 test
# 정확도
def evaluate(model, test_loader):
    model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(DEVICE), target.to(DEVICE)
            output = model(data)
            
            # test_loss - batch에 대한 loss를 sum 왜냐하면 원래는 batch 평균 값이 나온다.
            test_loss += F.cross_entropy(output, target, reduction='sum').item()
            
            # 정확도 = 16개의 batch 단위
            pred = output.max(1, keepdim=True)[1]
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)
    test_accuracy = 100 * correct / len(test_loader.dataset)
    
    return test_loss, test_accuracy

# %%
for epoch in range(1, EPOCHS + 1):
    train(model, train_loader, optimizer)
    test_loss, test_accuracy = evaluate(model, test_loader)

    print(f'At {epoch} Loss : {test_loss}, Accuracy : {test_accuracy}')
# Out:
# At 1 Loss : 0.5662492818593979, Accuracy : 79.87
# At 2 Loss : 0.4850934599399567, Accuracy : 82.57
# At 3 Loss : 0.4552450432956219, Accuracy : 84.08
# At 4 Loss : 0.42715604504942895, Accuracy : 84.85
# At 5 Loss : 0.40145926687717437, Accuracy : 85.54
# At 6 Loss : 0.39571314582824707, Accuracy : 86.13
# At 7 Loss : 0.3789045386195183, Accuracy : 86.43
# At 8 Loss : 0.380179030624032, Accuracy : 86.19
# At 9 Loss : 0.37291018963754174, Accuracy : 86.55
# At 10 Loss : 0.3639642284274101, Accuracy : 86.35
# At 11 Loss : 0.3642864726066589, Accuracy : 86.59
# At 12 Loss : 0.3465189216732979, Accuracy : 87.28
# At 13 Loss : 0.3475983699858189, Accuracy : 87.8
# At 14 Loss : 0.341296620605886, Accuracy : 88.03
# At 15 Loss : 0.33280083731412885, Accuracy : 87.99
# At 16 Loss : 0.34163214449435475, Accuracy : 87.61
# At 17 Loss : 0.34858897170722486, Accuracy : 87.34
# At 18 Loss : 0.324796340957284, Accuracy : 88.21
# At 19 Loss : 0.33044923189133407, Accuracy : 88.23
# ...

# %% [markdown]
# # 과적합과 드롭아웃
# 과적합을 방지하기 위해 validation loss가 증가하는 시점에 학습을 종료하는 Early Stopping,
# 학습 중 일부 뉴런을 끄는 Dropout, Data 변이를 통해 다양한 학습을 유도하는 Data Augmentation 방법을 적용할 수 있다.
